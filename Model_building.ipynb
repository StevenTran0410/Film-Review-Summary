# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns
import matplotlib.pyplot as plt
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter

# %%
def clean_text(text):
    # Remove <br> tags
    text = re.sub(r'<br\s*/?>', ' ', text)

    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Convert to lowercase
    text = text.lower()

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    stop_words.update(["mr", "ms", "mrs", "dr", "film", "movie", "really"])  # Add more stop words as needed                          film and movie was added due to the frequent they appear in both negative and positive
    text = ' '.join(word for word in text.split() if word not in stop_words)

    # Remove 1-2 length words
    text = ' '.join(word for word in text.split() if len(word) > 2)

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    text = ' '.join(lemmatizer.lemmatize(word) for word in text.split())

    return text

# %%
def load_data(path = "IMDB Dataset.csv"):
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(path)

    # Apply the clean_text and word2vec function to the 'review' column
    df['review'] = df['review'].apply(clean_text)

    # Get the cleaned review and sentiment as numpy arrays
    review = np.array(df['review'])
    sentiment = np.array(df['sentiment'])
    
    # Convert sentiment labels to 0s and 1s
    sentiment = np.where(sentiment == 'positive', 1, 0)
    
    return review, sentiment

review, sentiment= load_data()

# %%
# Count the number of positive and negative reviews
positive_count = np.sum(sentiment == 1)
negative_count = np.sum(sentiment == 0)

# Plot the distribution of positive and negative reviews
labels = ['Positive', 'Negative']
counts = [positive_count, negative_count]

plt.bar(labels, counts)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Distribution of Positive and Negative Reviews')
plt.show()
del positive_count, negative_count, labels, counts

# %%
# Separate positive and negative reviews
positive_reviews = ' '.join(review[sentiment == 1])
negative_reviews = ' '.join(review[sentiment == 0])

# Generate word clouds for positive and negative reviews
positive_wordcloud = WordCloud(width=400, height=400, background_color='white', colormap='Greens').generate(positive_reviews)
negative_wordcloud = WordCloud(width=400, height=400, background_color='white', colormap='Reds').generate(negative_reviews)

# Plot side-by-side subplots for positive and negative word clouds
fig, axes = plt.subplots(1, 2, figsize=(10, 6))

axes[0].imshow(positive_wordcloud, interpolation='bilinear')
axes[0].set_title('Positive Reviews')
axes[0].axis('off')

axes[1].imshow(negative_wordcloud, interpolation='bilinear')
axes[1].set_title('Negative Reviews')
axes[1].axis('off')

plt.tight_layout()
plt.show()
del positive_wordcloud  , negative_wordcloud

# %%
# Split the positive and negative reviews into individual words
positive_words = positive_reviews.split()
negative_words = negative_reviews.split()

# Count the frequency of each word in positive and negative reviews
positive_word_counts = Counter(positive_words)
negative_word_counts = Counter(negative_words)

# Select the top N most frequent words for positive and negative reviews
top_n = 10  # Change this value to select a different number of words
top_positive_words = positive_word_counts.most_common(top_n)
top_negative_words = negative_word_counts.most_common(top_n)

# Extract the words and their frequencies for positive and negative reviews
positive_labels = [word[0] for word in top_positive_words]
positive_frequencies = [word[1] for word in top_positive_words]

negative_labels = [word[0] for word in top_negative_words]
negative_frequencies = [word[1] for word in top_negative_words]

# Plot side-by-side bar charts for positive and negative word frequencies
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

axes[0].bar(positive_labels, positive_frequencies)
axes[0].set_xlabel('Words')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Top {} Most Frequent Words in Positive Reviews'.format(top_n))

axes[1].bar(negative_labels, negative_frequencies)
axes[1].set_xlabel('Words')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Top {} Most Frequent Words in Negative Reviews'.format(top_n))

plt.tight_layout()
plt.show()
del positive_reviews, negative_reviews, positive_words, negative_words, positive_word_counts, negative_word_counts

# %%
def preprocessing_data(review):
    # Tokenize the text data
    tokenized_reviews = [review.split() for review in review]

    # Train Word2Vec model on tokenized reviews
    word2vec_model = Word2Vec(tokenized_reviews, vector_size=100, window=5, min_count=1, workers=4)

    # Save Word2Vec model
    word2vec_model.save("word2vec_model.bin")

    # Convert text to word embeddings
    embedded_reviews = []
    for tokens in tokenized_reviews:
        embeddings = [word2vec_model.wv[word] for word in tokens if word in word2vec_model.wv]
        if embeddings:  # Check if embeddings list is not empty
            embedded_reviews.append(embeddings)
        else:
            embedded_reviews.append([np.zeros(100)])  # Replace empty list with zeros

    # Obtain fixed-size representation by averaging
    averaged_reviews = []
    for embeddings in embedded_reviews:
        averaged_reviews.append(np.mean(embeddings, axis=0))

    # Convert to numpy array
    averaged_reviews = np.array(averaged_reviews)
    
    return averaged_reviews

reviews = preprocessing_data(review)

# %%
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical

x_train, x_test, y_train, y_test = train_test_split(reviews, sentiment, test_size=0.3, stratify = sentiment)
y_cat_train = to_categorical(y_train,2)
y_cat_test = to_categorical(y_test,2) 
del reviews, review, sentiment

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Input, PReLU
from keras.initializers import RandomUniform

model = Sequential()

model.add(Input(100))

model.add(Dense(256))
model.add(PReLU(alpha_initializer=RandomUniform(minval=0.1, maxval=0.5)))  # Random uniform initialization
model.add(Dense(128))
model.add(PReLU(alpha_initializer=RandomUniform(minval=0.1, maxval=0.5)))  
model.add(Dense(64))
model.add(PReLU(alpha_initializer=RandomUniform(minval=0.1, maxval=0.5)))  
model.add(Dense(32))
model.add(PReLU(alpha_initializer=RandomUniform(minval=0.1, maxval=0.5)))  

model.add(Dropout(0.2))
model.add(Dense(2, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
model.load_weights("Sentiment Analysis Dense.h5")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               25856
#
#  p_re_lu (PReLU)             (None, 256)               256
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  p_re_lu_1 (PReLU)           (None, 128)               128
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  p_re_lu_2 (PReLU)           (None, 64)                64
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  p_re_lu_3 (PReLU)           (None, 32)                32
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense_4 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 69,634
# Trainable params: 69,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    monitor='accuracy', 
    patience=5, 
    mode='max'
)

# %%
model.fit(x_train, y_cat_train,
          epochs = 100,
          verbose = 1,
          validation_data = (x_test, y_cat_test),
          callbacks = [early_stopping])
# Out:
# Epoch 1/100
# 1094/1094 [==============================] - 9s 7ms/step - loss: 0.6075 - accuracy: 0.7934 - val_loss: 0.3587 - val_accuracy: 0.8423
# Epoch 2/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.3527 - accuracy: 0.8496 - val_loss: 0.3449 - val_accuracy: 0.8512
# Epoch 3/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.3367 - accuracy: 0.8564 - val_loss: 0.3609 - val_accuracy: 0.8405
# Epoch 4/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.3279 - accuracy: 0.8595 - val_loss: 0.3350 - val_accuracy: 0.8553
# Epoch 5/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.3241 - accuracy: 0.8616 - val_loss: 0.3216 - val_accuracy: 0.8619
# Epoch 6/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.3156 - accuracy: 0.8658 - val_loss: 0.3429 - val_accuracy: 0.8511
# Epoch 7/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.3100 - accuracy: 0.8690 - val_loss: 0.3248 - val_accuracy: 0.8604
# Epoch 8/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.3056 - accuracy: 0.8686 - val_loss: 0.3169 - val_accuracy: 0.8645
# Epoch 9/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2981 - accuracy: 0.8728 - val_loss: 0.3403 - val_accuracy: 0.8558
# Epoch 10/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2911 - accuracy: 0.8743 - val_loss: 0.3279 - val_accuracy: 0.8663
# Epoch 11/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2833 - accuracy: 0.8774 - val_loss: 0.3671 - val_accuracy: 0.8641
# Epoch 12/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2763 - accuracy: 0.8817 - val_loss: 0.3312 - val_accuracy: 0.8621
# Epoch 13/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2682 - accuracy: 0.8856 - val_loss: 0.3591 - val_accuracy: 0.8574
# Epoch 14/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2591 - accuracy: 0.8882 - val_loss: 0.3480 - val_accuracy: 0.8629
# Epoch 15/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2503 - accuracy: 0.8922 - val_loss: 0.3514 - val_accuracy: 0.8631
# Epoch 16/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2418 - accuracy: 0.8957 - val_loss: 0.3692 - val_accuracy: 0.8596
# Epoch 17/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2343 - accuracy: 0.8995 - val_loss: 0.3767 - val_accuracy: 0.8600
# Epoch 18/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2248 - accuracy: 0.9037 - val_loss: 0.4245 - val_accuracy: 0.8519
# Epoch 19/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2158 - accuracy: 0.9073 - val_loss: 0.4134 - val_accuracy: 0.8579
# Epoch 20/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2082 - accuracy: 0.9089 - val_loss: 0.4039 - val_accuracy: 0.8582
# Epoch 21/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.2030 - accuracy: 0.9138 - val_loss: 0.4062 - val_accuracy: 0.8557
# Epoch 22/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1909 - accuracy: 0.9184 - val_loss: 0.4539 - val_accuracy: 0.8543
# Epoch 23/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1820 - accuracy: 0.9219 - val_loss: 0.4865 - val_accuracy: 0.8546
# Epoch 24/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1759 - accuracy: 0.9248 - val_loss: 0.4984 - val_accuracy: 0.8555
# Epoch 25/100
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.1704 - accuracy: 0.9280 - val_loss: 0.5275 - val_accuracy: 0.8453
# Epoch 26/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1659 - accuracy: 0.9294 - val_loss: 0.4881 - val_accuracy: 0.8513
# Epoch 27/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1563 - accuracy: 0.9342 - val_loss: 0.5755 - val_accuracy: 0.8469
# Epoch 28/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1485 - accuracy: 0.9377 - val_loss: 0.5853 - val_accuracy: 0.8461
# Epoch 29/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1443 - accuracy: 0.9397 - val_loss: 0.6350 - val_accuracy: 0.8433
# Epoch 30/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1384 - accuracy: 0.9418 - val_loss: 0.5969 - val_accuracy: 0.8475
# Epoch 31/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1318 - accuracy: 0.9441 - val_loss: 0.6397 - val_accuracy: 0.8410
# Epoch 32/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1262 - accuracy: 0.9476 - val_loss: 0.7245 - val_accuracy: 0.8433
# Epoch 33/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1221 - accuracy: 0.9499 - val_loss: 0.7286 - val_accuracy: 0.8480
# Epoch 34/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1160 - accuracy: 0.9518 - val_loss: 0.7599 - val_accuracy: 0.8400
# Epoch 35/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1126 - accuracy: 0.9539 - val_loss: 0.6332 - val_accuracy: 0.8391
# Epoch 36/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1063 - accuracy: 0.9559 - val_loss: 0.7852 - val_accuracy: 0.8493
# Epoch 37/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.1066 - accuracy: 0.9567 - val_loss: 0.7090 - val_accuracy: 0.8414
# Epoch 38/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0953 - accuracy: 0.9611 - val_loss: 0.8798 - val_accuracy: 0.8420
# Epoch 39/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0988 - accuracy: 0.9596 - val_loss: 0.7669 - val_accuracy: 0.8383
# Epoch 40/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0919 - accuracy: 0.9633 - val_loss: 0.8010 - val_accuracy: 0.8378
# Epoch 41/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0886 - accuracy: 0.9628 - val_loss: 0.8760 - val_accuracy: 0.8397
# Epoch 42/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0860 - accuracy: 0.9654 - val_loss: 0.7716 - val_accuracy: 0.8343
# Epoch 43/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0815 - accuracy: 0.9673 - val_loss: 0.8569 - val_accuracy: 0.8419
# Epoch 44/100
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.0797 - accuracy: 0.9687 - val_loss: 0.9652 - val_accuracy: 0.8409
# Epoch 45/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0757 - accuracy: 0.9703 - val_loss: 0.8151 - val_accuracy: 0.8367
# Epoch 46/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0745 - accuracy: 0.9707 - val_loss: 0.8578 - val_accuracy: 0.8366
# Epoch 47/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0710 - accuracy: 0.9720 - val_loss: 1.0505 - val_accuracy: 0.8416
# Epoch 48/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0681 - accuracy: 0.9735 - val_loss: 1.0617 - val_accuracy: 0.8377
# Epoch 49/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0691 - accuracy: 0.9727 - val_loss: 0.8026 - val_accuracy: 0.8371
# Epoch 50/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0634 - accuracy: 0.9751 - val_loss: 1.1430 - val_accuracy: 0.8419
# Epoch 51/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0641 - accuracy: 0.9748 - val_loss: 1.0602 - val_accuracy: 0.8423
# Epoch 52/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0623 - accuracy: 0.9761 - val_loss: 1.0971 - val_accuracy: 0.8418
# Epoch 53/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0652 - accuracy: 0.9744 - val_loss: 1.1234 - val_accuracy: 0.8333
# Epoch 54/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0580 - accuracy: 0.9782 - val_loss: 1.1164 - val_accuracy: 0.8422
# Epoch 55/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0578 - accuracy: 0.9785 - val_loss: 1.3086 - val_accuracy: 0.8457
# Epoch 56/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0558 - accuracy: 0.9781 - val_loss: 1.1031 - val_accuracy: 0.8305
# Epoch 57/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0555 - accuracy: 0.9786 - val_loss: 1.0195 - val_accuracy: 0.8389
# Epoch 58/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0531 - accuracy: 0.9793 - val_loss: 0.9770 - val_accuracy: 0.8340
# Epoch 59/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0526 - accuracy: 0.9800 - val_loss: 1.0009 - val_accuracy: 0.8217
# Epoch 60/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0544 - accuracy: 0.9799 - val_loss: 0.8498 - val_accuracy: 0.8413
# Epoch 61/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0491 - accuracy: 0.9809 - val_loss: 1.2679 - val_accuracy: 0.8371
# Epoch 62/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0502 - accuracy: 0.9807 - val_loss: 1.1177 - val_accuracy: 0.8466
# Epoch 63/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0484 - accuracy: 0.9814 - val_loss: 1.1280 - val_accuracy: 0.8412
# Epoch 64/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0465 - accuracy: 0.9831 - val_loss: 1.1807 - val_accuracy: 0.8401
# Epoch 65/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0464 - accuracy: 0.9821 - val_loss: 1.0029 - val_accuracy: 0.8310
# Epoch 66/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0422 - accuracy: 0.9841 - val_loss: 1.3957 - val_accuracy: 0.8422
# Epoch 67/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0462 - accuracy: 0.9827 - val_loss: 1.1702 - val_accuracy: 0.8362
# Epoch 68/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0397 - accuracy: 0.9854 - val_loss: 1.3456 - val_accuracy: 0.8376
# Epoch 69/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0444 - accuracy: 0.9836 - val_loss: 0.9985 - val_accuracy: 0.8260
# Epoch 70/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0429 - accuracy: 0.9832 - val_loss: 1.3561 - val_accuracy: 0.8407
# Epoch 71/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0403 - accuracy: 0.9850 - val_loss: 1.3322 - val_accuracy: 0.8395
# Epoch 72/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0408 - accuracy: 0.9842 - val_loss: 1.2170 - val_accuracy: 0.8393
# Epoch 73/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0402 - accuracy: 0.9856 - val_loss: 1.2721 - val_accuracy: 0.8431
# Epoch 74/100
# 1094/1094 [==============================] - 7s 7ms/step - loss: 0.0418 - accuracy: 0.9848 - val_loss: 1.0904 - val_accuracy: 0.8432
# Epoch 75/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0410 - accuracy: 0.9844 - val_loss: 1.2377 - val_accuracy: 0.8443
# Epoch 76/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0370 - accuracy: 0.9869 - val_loss: 1.3923 - val_accuracy: 0.8423
# Epoch 77/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0378 - accuracy: 0.9865 - val_loss: 1.2519 - val_accuracy: 0.8319
# Epoch 78/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0406 - accuracy: 0.9852 - val_loss: 1.1337 - val_accuracy: 0.8410
# Epoch 79/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0337 - accuracy: 0.9881 - val_loss: 1.4034 - val_accuracy: 0.8355
# Epoch 80/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0400 - accuracy: 0.9854 - val_loss: 1.3053 - val_accuracy: 0.8379
# Epoch 81/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0337 - accuracy: 0.9878 - val_loss: 1.4140 - val_accuracy: 0.8400
# Epoch 82/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0380 - accuracy: 0.9851 - val_loss: 1.2591 - val_accuracy: 0.8447
# Epoch 83/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0350 - accuracy: 0.9877 - val_loss: 1.1671 - val_accuracy: 0.8391
# Epoch 84/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 1.6580 - val_accuracy: 0.8413
# Epoch 85/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0362 - accuracy: 0.9870 - val_loss: 0.9475 - val_accuracy: 0.8275
# Epoch 86/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0319 - accuracy: 0.9882 - val_loss: 1.4403 - val_accuracy: 0.8425
# Epoch 87/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0343 - accuracy: 0.9874 - val_loss: 1.3931 - val_accuracy: 0.8415
# Epoch 88/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0351 - accuracy: 0.9865 - val_loss: 1.2009 - val_accuracy: 0.8357
# Epoch 89/100
# 1094/1094 [==============================] - 7s 6ms/step - loss: 0.0315 - accuracy: 0.9884 - val_loss: 1.1610 - val_accuracy: 0.8312

# %%
#Save model
model.save('Sentiment Analysis Dense.h5')

# %%
def word2vec(review, word2vec_model_path="word2vec_model.bin"):
    # Tokenize the text data
    tokenized_reviews = review.split()  # Split the string into tokens

    # Load Word2Vec model
    word2vec_model = Word2Vec.load(word2vec_model_path)

    # Convert text to word embeddings
    embeddings = [word2vec_model.wv[word] for word in tokenized_reviews if word in word2vec_model.wv]

    # Obtain fixed-size representation by averaging
    averaged_reviews = np.mean(embeddings, axis=0)

    # Convert to numpy array
    averaged_reviews = np.array([averaged_reviews])
    
    return averaged_reviews

# %%
summary = ["Negative","Positive"]
text = input()
text = clean_text(text)
text = word2vec(text)
text = text.reshape(1, 100)
result = np.argmax(model.predict(text))
summary[result]
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 'Negative'
